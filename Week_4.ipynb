# %% [markdown]
# ## Week 4 handin

# %% [markdown]
# # Exercise 1

# %% [markdown]
# 1. Open the file './data/befkbhalderstatkode.csv'
# 2. Turn the csv file into a numpy ndarray with np.genfromtxt(filename, delimiter=',', dtype=np.uint, skip_header=1)
# Using this data:
# neighb = {1: 'Indre By', 2: 'Østerbro', 3: 'Nørrebro', 4: 'Vesterbro/Kgs. Enghave',
#        5: 'Valby', 6: 'Vanløse', 7: 'Brønshøj-Husum', 8: 'Bispebjerg', 9: 'Amager Øst',
#        10: 'Amager Vest', 99: 'Udenfor'}
# 3. Find out how many people lived in each of the 11 areas in 2015
# 4. Make a bar plot to show the size of each city area from the smallest to the largest
# 5. Create a boolean mask to find out how many people above 65 years lived in Copenhagen in 2015
# 6. How many of those were from the other nordic countries (not dk)
# 7. Make a line plot showing the changes of number of people in vesterbro and østerbro from 1992 to 2015

# %% [markdown]
# ## Status

# %% [markdown]
# I have completed all the tasks in exercise 1.

# %%
#Exercise 1.1 and Exercise 1.2
from modules import ex1_Week4 as ex1
ex1.file_to_numpy()
# Out:
# <class 'numpy.ndarray'>  of size:  2712585
# The skip_header=1 means that we have only the data
#
# first line:
#  [2015    1    0 5100  614]
# last line
#  [1992   99   93 5100    1]

# %%
#Exercise 1.3
from modules import ex1_Week4 as ex1
ex1.count_people_city()
# Out:
# Indre By
# 51937
# Østerbro
# 75113
# Nørrebro
# 78802
# Vesterbro/Kgs. Enghave
# 61623
# Valby
# 51727
# Vanløse
# 39537
# Brønshøj-Husum
# 43908
# Bispebjerg
# 53604
# Amager Øst
# 55205
# Amager Vest
# 64967
# Udenfor
# 3872

# %%
#Exercise 1.4
from modules import ex1_Week4 as ex1
ex1.getBarWithPubInCity()

# %%
#Exercise 1.5
from modules import ex1_Week4 as ex1
ex1.above65years()
# Out:
# sum of all the pople above 65 years old
#  55700

# %%
#Exercise 1.6
from modules import ex1_Week4 as ex1
ex1.above65years_FromNordicCountries()
# Out:
# sum of all the pople above 65 years old and from nordic countries besides Denmark
#  0

# %%
#Exercise 1.7
from modules import ex1_Week4 as ex1
ex1.line_plot_østerbro_and_vesterbro()
