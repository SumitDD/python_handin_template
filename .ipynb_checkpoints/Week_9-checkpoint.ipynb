# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import sklearn.linear_model


#   1. Programatically download the data from the above link.
#    2. Import the data into a Pandas dataframe.
 #   3. Show the head of the Pandas dataframe.
df = pd.read_csv('https://think.cs.vt.edu/corgis/datasets/csv/cars/cars.csv%27)
df.head()


# Make == Honda
ts_honda = df[df['Identification.Make']=='Honda']

# Fueltype == Gasoline
ts_fuel = ts_honda[ts_honda['Fuel Information.Fuel Type']=='Gasoline']

#  Only use 2 features: 'Fuel Information.Highway mpg' and 'Engine Information.Engine Statistics.Horsepower'
two_features = ts_fuel[["Fuel Information.Highway mpg","Engine Information.Engine Statistics.Horsepower" ]]

# Normalize data (reduce values to be between 0 and 1)
normalized = two_features.apply(lambda x: (x - x.min()) / (x.max() - x.min()))

normalized = normalized.clip(lower=0.00, upper=1.00)



# 5. Perform linear regression where x = horsepower and y = mpg

two_features.plot.scatter(x=1, y=0)
plt.plot([120, 260], [20, 40])

# 6. What is the coefficient (slope) of your model? What does this number mean?

horsepower = df[["Engine Information.Engine Statistics.Horsepower"]]
highway = df[["Fuel Information.Highway mpg"]]

model = sklearn.linearmodel.LinearRegression()
model.fit(horsepower, highway)
model.coef

# 7. According to your model, what is y when x=1.

predicted = model.predict([[1]])
print('When x is onemeans y will be {}'.format(predicted[0]))


# 8.  Show the regression line on a scatterplot with the other datapoints.
# Out:
#    Dimensions.Height  Dimensions.Length  Dimensions.Width  \
# 0                140                143               202
# 1                140                143               202
# 2                140                143               202
# 3                140                143               202
# 4                140                143               202
#
#   Engine Information.Driveline                Engine Information.Engine Type  \
# 0              All-wheel drive          Audi 3.2L 6 cylinder 250hp 236ft-lbs
# 1            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 2            Front-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 3              All-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
# 4              All-wheel drive  Audi 2.0L 4 cylinder 200 hp 207 ft-lbs Turbo
#
#    Engine Information.Hybrid  Engine Information.Number of Forward Gears  \
# 0                       True                                           6
# ...
